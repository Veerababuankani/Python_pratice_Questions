# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
 # 1.in machine learing alogrithm will develop models by using maths
# maths allow only numbers
# so it is very important, you need to pass numerical data only
# so we need to convert categorial data to numerical data
# for that we have encoding methods
# <encoding>
#  ------------>1.label encoder
#                      *map method
#                       *np.where
#                        *labelencoder package from sklearn
#---------------->2.one hot encoder
 #                      *pd.get_dummies()

# %%
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
################################
adult_df['sex'].unique()
dict={'Male':1,'Female':0}
adult_df['sex'].map(dict)
#do you want to create a new column
#do u want  overwrite the new column
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    1
# 32560    0
# Name: sex, Length: 32561, dtype: int64

# %%
#create a new column
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
################################
adult_df['sex'].unique()
dict={'Male':1,'Female':0}
adult_df['sex_123']=adult_df['sex'].map(dict)
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
#drop the column 'sex_123'
adult_df.drop('sex_123',
              axis=1,
              inplace=True)
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
 #create a new column
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
####################################
adult_df['sex'].unique()
dict={'Male':1,'Female':0}
adult_df['sex']=adult_df['sex'].map(dict)
adult_df
#in map method inplace = true is not there
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race  sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    1
# ...

# %%
adult_df['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
num=len(adult_df['workclass'].unique())
dict1={}
for i in range(num):
    print(adult_df['workclass'].unique()[i],i)
# Out:
# State-gov 0
# Self-emp-not-inc 1
# Private 2
# Federal-gov 3
# Local-gov 4
# ? 5
# Self-emp-inc 6
# Without-pay 7
# Never-worked 8

# %%
lables=adult_df['workclass'].unique()
num=len(adult_df['workclass'].unique())
dict1={}
for i in range(num):
    dict1[lables[i]]=i
dict1
# Out:
# {'State-gov': 0,
#  'Self-emp-not-inc': 1,
#  'Private': 2,
#  'Federal-gov': 3,
#  'Local-gov': 4,
#  '?': 5,
#  'Self-emp-inc': 6,
#  'Without-pay': 7,
#  'Never-worked': 8}

# %%
lables=adult_df['workclass'].unique()
num=len(adult_df['workclass'].unique())
{lables[i]:i for i in range(num)}
# Out:
# {'State-gov': 0,
#  'Self-emp-not-inc': 1,
#  'Private': 2,
#  'Federal-gov': 3,
#  'Local-gov': 4,
#  '?': 5,
#  'Self-emp-inc': 6,
#  'Without-pay': 7,
#  'Never-worked': 8}

# %%
#method-2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
#np.where() is for binary conditions
#which means it is applicable only for two labels
#no.where(<condition>,<Truevalue>,<Falsevalue>)
#for Eaxample case_status has labels
#condition:<>col_values>=='certified '
#true value:replace all certified values with o
#false value :replace all denied values with 1

# %%
con=adult_df['sex']=='Male'
adult_df['sex']=np.where(con,0,1)

# %%
adult_df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race  sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    0
# 1  Married-civ-spouse    Exec-managerial        Husband  White    0
# 2            Divorced  Handlers-cleaners  Not-in-family  White    0
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    0
# 4  Married-civ-spouse     Prof-specialty           Wife  Black    1
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
#label and coder

# %% [markdown]
# from skleran.pre

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
adult_df['sex']=le.fit_transform(adult_df['sex'])
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race  sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
 adult_df.head(10)
# Out:
#   Cell In[19], line 6
#     adult_df.head(10)
#     ^
# IndentationError: unexpected indent

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
#print(adult_df[['workclass','sex']].head(10))
##############from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
adult_df['workclass']=le.fit_transform(adult_df['workclass'])
adult_df['sex']=le.fit_transform(adult_df['sex'])
#print(adult_df[['workclass','sex']].head(10))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
##print(adult_df[['workclass','sex']].head(10))
##############from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
adult_df['workclass']=le.fit_transform(adult_df['workclass'])
adult_df['sex']=le.fit_transform(adult_df['sex'])
#print(adult_df[['workclass','sex']].head(10))

print(adult_df['workclass'][:10])
#le.inverse_transform(adult_df['workclass'])
# Out:
# 0    7
# 1    6
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    6
# 8    4
# 9    4
# Name: workclass, dtype: int32

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
###########################
pd.get_dummies(adult_df['sex'])
# Out:
#        Female   Male
# 0       False   True
# 1       False   True
# 2       False   True
# 3       False   True
# 4        True  False
# ...       ...    ...
# 32556    True  False
# 32557   False   True
# 32558    True  False
# 32559   False   True
# 32560    True  False
#
# [32561 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
pd.get_dummies(adult_df['workclass'])
# Out:
#            ?  Federal-gov  Local-gov  Never-worked  Private  Self-emp-inc  \
# 0      False        False      False         False    False         False
# 1      False        False      False         False    False         False
# 2      False        False      False         False     True         False
# 3      False        False      False         False     True         False
# 4      False        False      False         False     True         False
# ...      ...          ...        ...           ...      ...           ...
# 32556  False        False      False         False     True         False
# 32557  False        False      False         False     True         False
# 32558  False        False      False         False     True         False
# 32559  False        False      False         False     True         False
# 32560  False        False      False         False    False          True
#
#        Self-emp-not-inc  State-gov  Without-pay
# ...

# %%
pd.get_dummies(adult_df,columns=['workclass'],dtype='int')
# Out:
#        age  fnlwgt   education  education-num      marital-status  \
# 0       39   77516   Bachelors             13       Never-married
# 1       50   83311   Bachelors             13  Married-civ-spouse
# 2       38  215646     HS-grad              9            Divorced
# 3       53  234721        11th              7  Married-civ-spouse
# 4       28  338409   Bachelors             13  Married-civ-spouse
# ...    ...     ...         ...            ...                 ...
# 32556   27  257302  Assoc-acdm             12  Married-civ-spouse
# 32557   40  154374     HS-grad              9  Married-civ-spouse
# 32558   58  151910     HS-grad              9             Widowed
# 32559   22  201490     HS-grad              9       Never-married
# 32560   52  287927     HS-grad              9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  ...  \
# 0           Adm-clerical  Not-in-family  White    Male          2174  ...
# ...
