# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <img class="s-img" width="189.9" height="94.9" alt="donde puedo conocer sobre boxplot, en el curso de visualización de ..." title="donde puedo conocer sobre boxplot, en el curso de visualización de ..." data-pos="11" src="https://up.yimg.com/ib/th?id=OIP.frHs-G-5UHClbb2Nd89MUQHaDt&amp;pid=Api&amp;rs=1&amp;c=1&amp;qlt=95&amp;w=189&amp;h=94">

# %%
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")

# %%
plt.boxplot(adult_df['education-num'],vert=False)
#plt.hist(adult_df['education-num'])
plt.show()
#black dots are nothing but outliers

# %%
q1=np.percentile(adult_df['education-num'],25)
q2=np.percentile(adult_df['education-num'],50)
q3=np.percentile(adult_df['education-num'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
con1=adult_df['education-num']>UB
con2=adult_df['education-num']<LB
outliers=adult_df['education-num'][con1|con2]
#########
outliers_data=outliers.values

outliers_data
len(outliers_data)
# Out:
# 3820

# %%
def outliers():
    q1=np.percentile(adult_df['education-num'],25)
    q2=np.percentile(adult_df['education-num'],50)
    q3=np.percentile(adult_df['education-num'],75)
    IQR=q3-q1
    UB=q3+1.5*IQR
    LB=q3-1.5*IQR
    con1=adult_df['education-num']>UB
    con2=adult_df['education-num']<LB
    ##################################
    outliers=adult_df['education-num'][con1|con2]
    ###################################
    outliers_data=outliers.values
    return(outliers_data)
outliers_data=outliers()
len(outliers_data)
# Out:
# 3820

# %%
q1=np.percentile(adult_df['education-num'],25)
q2=np.percentile(adult_df['education-num'],50)
q3=np.percentile(adult_df['education-num'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
con1=adult_df['education-num']>UB
con2=adult_df['education-num']<LB
#################################
adult_df[con1|con2]
###################################
# Out:
#        age    workclass  fnlwgt education  education-num  \
# 3       53      Private  234721      11th              7
# 6       49      Private  160187       9th              5
# 15      34      Private  245487   7th-8th              4
# 18      38      Private   28887      11th              7
# 22      35  Federal-gov   76845       9th              5
# ...    ...          ...     ...       ...            ...
# 32515   66  Federal-gov   47358      10th              6
# 32517   36      Private  131459   7th-8th              4
# 32522   58      Private  147707      11th              7
# 32526   32      Private  211349      10th              6
# 32551   32      Private   34066      10th              6
#
#               marital-status         occupation   relationship  \
# 3         Married-civ-spouse  Handlers-cleaners        Husband
# 6      Married-spouse-absent      Other-service  Not-in-family
# 15        Married-civ-spouse   Transport-moving        Husband
# ...

# %%
len(outliers_data),len(adult_df),len(outliers_data)/len(adult_df)
# Out:
# (3820, 32561, 0.11731826418107552)

# %%
#case1
#Removal of ouliters
#we have 3820 ouliters in education_num column
#that means we need to remove 3820 rows frome entire data

# %%
q1=np.percentile(adult_df['education-num'],25)
q2=np.percentile(adult_df['education-num'],50)
q3=np.percentile(adult_df['education-num'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
con1=adult_df['education-num']<UB
con2=adult_df['education-num']>LB
##################################
non_outliers=adult_df[con1&con2]
###################################
non_outliers
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 4       28           Private  338409   Bachelors             13
# 5       37           Private  284582     Masters             14
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
plt.title('non_outliers')
plt.hist(non_outliers['education-num']
         ,bins=9)

plt.subplot(2,2,2)
plt.title('original_data')
plt.hist(adult_df['education-num']
         ,bins=9)

plt.subplot(2,2,3)
plt.title('non_outliers')
plt.boxplot(non_outliers['education-num'],vert=False)

plt.subplot(2,2,4)
plt.title('original_data')
plt.boxplot(adult_df['education-num'],vert=False)
plt.show()

# %%
UB,LB
# Out:
# (16.5, 7.5)

# %%
for i in adult_df['education-num'].values:
# Out:
#   Cell In[122], line 2
#
#     ^
# SyntaxError: incomplete input

# %%
q1=np.percentile(adult_df['education-num'],25)
q2=np.percentile(adult_df['education-num'],50)
q3=np.percentile(adult_df['education-num'],75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q3-1.5*IQR
con1=adult_df['education-num']>UB
con2=adult_df['education-num']<LB
##################################
outliers=adult_df['education-num'][con1|con2]

# %%
len(outliers)

# %%
new_data=[]
for i in adult_df['education-num']:
    if i>UB or i<LB:
        new_data.append(adult_df['education-num'].median())
    else:
        new_data.append(i)
len(new_data)

# %%
dict1={'col1':[1,2,3,4],
      "co2":["a","b","c","d"]}
data=pd.DataFrame(dict1)
#i want to impute with a value 100 in c0l1
#which are haveing values>2
#col1 col2
#1     a
#2     b
#100   c
#100    d

# %%
# np.where will take 3 arguments values
#condition : con=data['col']>2
#if that condition is true will provide the value:100
#if that condition is flase will keep the same value: data['col1']
#np.where(<condition>,<true_value>,<false_value>)

# %%
data['col1']>2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: col1, dtype: bool

# %%
con=data['col1']>2
np.where(con,100,data['col1'])
#binary condition
#true and flase 
#if else
# Out:
# array([  1,   2, 100, 100], dtype=int64)

# %%
 data['new_col']=[100,200,300,400]

# %%
data
# Out:
#    col1 co2  new_col
# 0     1   a      100
# 1     2   b      200
# 2     3   c      300
# 3     4   d      400

# %%
con=data['col1']>2
data['col3']=np.where(con,100,data['col1'])
data
# Out:
#    col1 co2  new_col  col3
# 0     1   a      100     1
# 1     2   b      200     2
# 2     3   c      300   100
# 3     4   d      400   100

# %%
con=data['col1']>2
data['col1']=np.where(con,100,data['col1'])
data
# Out:
#    col1 co2  new_col  col3
# 0     1   a      100     1
# 1     2   b      200     2
# 2   100   c      300   100
# 3   100   d      400   100

# %%
data.drop(['new_col','col3'],axis=1,inplace=True)
data
# Out:
#    col1 co2
# 0     1   a
# 1     2   b
# 2   100   c
# 3   100   d

# %%
con1=(adult_df['education-num']>UB)
con2=(adult_df['education-num']<LB)
con=(con1|con2)
en_df=adult_df['education-num'].median()
adult_df['education-num']=np.where(con,
                                   en_df,
                                   adult_df['education-num'])

# %%
plt.boxplot(adult_df['education-num'])
plt.show()
