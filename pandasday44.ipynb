# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv"
visa_df=pd.read_csv(file_path)

# %%
visa_df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
visa_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
visa_df['workclass']
# Out:
# 0               State-gov
# 1        Self-emp-not-inc
# 2                 Private
# 3                 Private
# 4                 Private
#                ...
# 32556             Private
# 32557             Private
# 32558             Private
# 32559             Private
# 32560        Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
type(visa_df['workclass'])
# Out:
# pandas.core.series.Series

# %%
visa_df[['workclass']]
#cols=['workclass']
#visa_df[cols]
# Out:
#               workclass
# 0             State-gov
# 1      Self-emp-not-inc
# 2               Private
# 3               Private
# 4               Private
# ...                 ...
# 32556           Private
# 32557           Private
# 32558           Private
# 32559           Private
# 32560      Self-emp-inc
#
# [32561 rows x 1 columns]

# %%
type(visa_df[['workclass']])
# Out:
# pandas.core.frame.DataFrame

# %%
visa_df.workclass
# Out:
# 0               State-gov
# 1        Self-emp-not-inc
# 2                 Private
# 3                 Private
# 4                 Private
#                ...
# 32556             Private
# 32557             Private
# 32558             Private
# 32559             Private
# 32560        Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
cols=['workclass','education','education-num']
visa_df[cols]
# Out:
#               workclass   education  education-num
# 0             State-gov   Bachelors             13
# 1      Self-emp-not-inc   Bachelors             13
# 2               Private     HS-grad              9
# 3               Private        11th              7
# 4               Private   Bachelors             13
# ...                 ...         ...            ...
# 32556           Private  Assoc-acdm             12
# 32557           Private     HS-grad              9
# 32558           Private     HS-grad              9
# 32559           Private     HS-grad              9
# 32560      Self-emp-inc     HS-grad              9
#
# [32561 rows x 3 columns]

# %%
visa_df['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
len(visa_df['workclass'].unique())
# Out:
# 9

# %%
len(visa_df['workclass'])
# Out:
# 32561

# %%
visa_df['workclass'].nunique()
# Out:
# 9

# %%
visa_df['workclass']=="Self-emp-not-inc"
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: workclass, Length: 32561, dtype: bool

# %%
len(visa_df[visa_df['workclass']=="Private"])
# Out:
# 22696

# %%
workclass1=visa_df['sex'].unique()
for i in workclass1:
    count=len(visa_df[visa_df['sex']=="i"])
    print(i, ':' ,count)
# Out:
# Male : 0
# Female : 0

# %%
len(visa_df[visa_df['sex']]=="Male")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 len(visa_df[visa_df['sex']]=="Male")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
workclass=visa_df['workclass'].unique()
for i in workclass:
    print(len(visa_df[visa_df['workclass']=='i']))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
workclass = visa_df['workclass'].unique()
print(workclass)
# Out:
# ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']

# %%
for i in workclass:
    filtered_df = visa_df[visa_df['workclass'] == i]
    print(f"Workclass: {i}, Count: {len(filtered_df)}")
# Out:
# Workclass: State-gov, Count: 1298
# Workclass: Self-emp-not-inc, Count: 2541
# Workclass: Private, Count: 22696
# Workclass: Federal-gov, Count: 960
# Workclass: Local-gov, Count: 2093
# Workclass: ?, Count: 1836
# Workclass: Self-emp-inc, Count: 1116
# Workclass: Without-pay, Count: 14
# Workclass: Never-worked, Count: 7

# %%
visa_df[visa_df['workclass']=='i']
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
for i in workclass:
    print(i)
# Out:
# State-gov
# Self-emp-not-inc
# Private
# Federal-gov
# Local-gov
# ?
# Self-emp-inc
# Without-pay
# Never-worked

# %%
for i in workclass:
    print(i,"-->count:",len(visa_df[visa_df['workclass']]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 2
#       1 for i in workclass:
# ----> 2     print(i,"-->count:",len(visa_df[visa_df['workclass']]))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
for i in workclass:
    print(i)
# Out:
# State-gov
# Self-emp-not-inc
# Private
# Federal-gov
# Local-gov
# ?
# Self-emp-inc
# Without-pay
# Never-worked

# %%
visa_df[visa_df['workclass'] == i]
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 5361    18  Never-worked  206359          10th              6
# 10845   23  Never-worked  188535       7th-8th              4
# 14772   17  Never-worked  237272          10th              6
# 20337   18  Never-worked  157131          11th              7
# 23232   20  Never-worked  462294  Some-college             10
# 32304   30  Never-worked  176673       HS-grad              9
# 32314   18  Never-worked  153663  Some-college             10
#
#            marital-status occupation   relationship   race     sex  \
# 5361        Never-married          ?      Own-child  White    Male
# 10845            Divorced          ?  Not-in-family  White    Male
# 14772       Never-married          ?      Own-child  White    Male
# 20337       Never-married          ?      Own-child  White  Female
# 23232       Never-married          ?      Own-child  Black    Male
# ...

# %%
len(visa_df[visa_df['workclass'] == "State-gov"])
# Out:
# 1298

# %%
for i in workclass:
    df=len(visa_df[visa_df['workclass']==i])
    print("workclass:{}--------->count:{}".format(i,df))
# Out:
# workclass:State-gov--------->count:1298
# workclass:Self-emp-not-inc--------->count:2541
# workclass:Private--------->count:22696
# workclass:Federal-gov--------->count:960
# workclass:Local-gov--------->count:2093
# workclass:?--------->count:1836
# workclass:Self-emp-inc--------->count:1116
# workclass:Without-pay--------->count:14
# workclass:Never-worked--------->count:7

# %%
c=[]
for i in workclass:
    df=len(visa_df[visa_df['workclass']==i])
    c.append(df)
print(c)
# Out:
# [1298, 2541, 22696, 960, 2093, 1836, 1116, 14, 7]

# %%
workclaass=visa_df['workclass'].unique()
count=[len(visa_df[visa_df['workclass']==i]) for i in workclass]
workclass_df=pd.DataFrame(zip(workclass,count),
             columns=['workclass','count'])
workclass_df.to_csv('workclass_info.csv',index=False)

# %%
visa_df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
pd.Series(count)
# Out:
# 0     1298
# 1     2541
# 2    22696
# 3      960
# 4     2093
# 5     1836
# 6     1116
# 7       14
# 8        7
# dtype: int64

# %%
pd.Series(count,workclass)
# Out:
# State-gov            1298
# Self-emp-not-inc     2541
# Private             22696
# Federal-gov           960
# Local-gov            2093
# ?                    1836
# Self-emp-inc         1116
# Without-pay            14
# Never-worked            7
# dtype: int64

# %%
visa_df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
workclass1=visa_df['workclass'].value_counts().keys()
count=visa_df['workclass'].value_counts().values
pd.DataFrame(zip(workclass,count),columns=['workclass','values'])
# Out:
#           workclass  values
# 0         State-gov   22696
# 1  Self-emp-not-inc    2541
# 2           Private    2093
# 3       Federal-gov    1836
# 4         Local-gov    1298
# 5                 ?    1116
# 6      Self-emp-inc     960
# 7       Without-pay      14
# 8      Never-worked       7

# %%
dict1=dict(visa_df['workclass'].value_counts())
print(dict1)
pd.DataFrame(dict1,index=['count'])
# Out:
# {'Private': 22696, 'Self-emp-not-inc': 2541, 'Local-gov': 2093, '?': 1836, 'State-gov': 1298, 'Self-emp-inc': 1116, 'Federal-gov': 960, 'Without-pay': 14, 'Never-worked': 7}
#        Private  Self-emp-not-inc  Local-gov     ?  State-gov  Self-emp-inc  \
# count    22696              2541       2093  1836       1298          1116
#
#        Federal-gov  Without-pay  Never-worked
# count          960           14             7

# %%
dict1=dict(visa_df['workclass'].value_counts())
v1=dict1.keys()
v2=dict1.values()
pd.DataFrame(zip(v1,v2),columns=['workclass','count'])
# Out:
#           workclass  count
# 0           Private  22696
# 1  Self-emp-not-inc   2541
# 2         Local-gov   2093
# 3                 ?   1836
# 4         State-gov   1298
# 5      Self-emp-inc   1116
# 6       Federal-gov    960
# 7       Without-pay     14
# 8      Never-worked      7

# %%
workclass_df
#1column=categorical:workclass
#2column=numerical:count
#barplot or piechart
# Out:
#           workclass  count
# 0         State-gov   1298
# 1  Self-emp-not-inc   2541
# 2           Private  22696
# 3       Federal-gov    960
# 4         Local-gov   2093
# 5                 ?   1836
# 6      Self-emp-inc   1116
# 7       Without-pay     14
# 8      Never-worked      7

# %%
plt.figure(figsize=(14,6))
plt.bar('workclass',
        'count',
        data=workclass_df)
# Out:
# <BarContainer object of 9 artists>

# %%
visa_df['workclass'].value_counts()
workclass=visa_df['workclass'].value_counts().keys()
count=visa_df['workclass'].value_counts().values
work_data=pd.DataFrame(zip(workclass,count),
                       columns=['workclass','count'])
work_data
plt.figure(figsize=(14,6))
plt.bar('workclass','count',
       data=work_data)
plt.tittle('Bar Chart')
plt.xlabel('workclass')
plt.ylabel('count')
# Out:
# <BarContainer object of 9 artists>
