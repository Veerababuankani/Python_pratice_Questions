# %%
pip install pywhatkit styletext
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement styletext (from versions: none)
# ERROR: No matching distribution found for styletext

# %%
import pywhatkit as kit
import time
import styletext
import random

# Replace with the recipient's WhatsApp number (include country code)
phone_number = "+1234567890"

# Number of times to send the message
count = 5  

for i in range(1, count + 1):
    # Select a random font
    font_choice = random.choice(list(styletext.FONTS.keys()))  # Ensures a valid font is picked
    
    # Style the message with the chosen font
    styled_message = styletext.FontStyle("By using Python code, I am preparing a MSG", font=font_choice)

    # Create the final message with repetition count
    message = f"{styled_message} for {i} {'time' if i == 1 else 'times'} repetition"

    # Send the WhatsApp message instantly
    kit.sendwhatmsg_instantly(phone_number, message)
    
    print(f"Message {i} sent: {message}")  # Print message to verify
    
    time.sleep(5)  # Delay to prevent spam detection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pywhatkit as kit
#       2 import time
# ----> 3 import styletext
#       4 import random
#       6 # Replace with the recipient's WhatsApp number (include country code)
#
# ModuleNotFoundError: No module named 'styletext'

# %%
import pywhatkit as kit
import time
import random

# Replace with recipient's WhatsApp number (include country code)
phone_number = "+91 9491201336"

# Number of times to send the message
count = 5  

# Function to apply a random font style
def apply_random_font(text):
    font_type = random.randint(1, 4)  # Randomly select a font style
    
    if font_type == 1:
        # Bold font
        return "".join(chr(0x1D400 + ord(c) - ord("A")) if "A" <= c <= "Z" else
                       chr(0x1D41A + ord(c) - ord("a")) if "a" <= c <= "z" else c for c in text)
    
    elif font_type == 2:
        # Italic font
        return "".join(chr(0x1D434 + ord(c) - ord("A")) if "A" <= c <= "Z" else
                       chr(0x1D44E + ord(c) - ord("a")) if "a" <= c <= "z" else c for c in text)
    
    elif font_type == 3:
        # Script font
        return "".join(chr(0x1D49C + ord(c) - ord("A")) if "A" <= c <= "Z" else
                       chr(0x1D4B6 + ord(c) - ord("a")) if "a" <= c <= "z" else c for c in text)
    
    else:
        # Double-struck font
        return "".join(chr(0x1D538 + ord(c) - ord("A")) if "A" <= c <= "Z" else
                       chr(0x1D552 + ord(c) - ord("a")) if "a" <= c <= "z" else c for c in text)

for i in range(1, count + 1):
    # Style the message with a random font
    styled_message = apply_random_font("By using Python code, I am preparing a MSG")

    # Create the final message with repetition count
    message = f"{styled_message} for {i} {'time' if i == 1 else 'times'} repetition"

    # Send the WhatsApp message instantly
    kit.sendwhatmsg_instantly(phone_number, message)
    
    print(f"Message {i} sent: {message}")  # Print message to verify
    
    time.sleep(5)  # Delay to prevent spam detection
# Out:
# Message 1 sent: 𝐵𝑦 𝑢𝑠𝑖𝑛𝑔 𝑃𝑦𝑡𝑕𝑜𝑛 𝑐𝑜𝑑𝑒, 𝐼 𝑎𝑚 𝑝𝑟𝑒𝑝𝑎𝑟𝑖𝑛𝑔 𝑎 𝑀𝑆𝐺 for 1 time repetition
# Message 2 sent: 𝒝𝓎 𝓊𝓈𝒾𝓃𝒼 𝒫𝓎𝓉𝒽𝓄𝓃 𝒸𝓄𝒹𝒺, 𝒤 𝒶𝓂 𝓅𝓇𝒺𝓅𝒶𝓇𝒾𝓃𝒼 𝒶 𝒨𝒮𝒢 for 2 times repetition
# Message 3 sent: 𝔹𝕪 𝕦𝕤𝕚𝕟𝕘 𝕇𝕪𝕥𝕙𝕠𝕟 𝕔𝕠𝕕𝕖, 𝕀 𝕒𝕞 𝕡𝕣𝕖𝕡𝕒𝕣𝕚𝕟𝕘 𝕒 𝕄𝕊𝔾 for 3 times repetition
# Message 4 sent: 𝒝𝓎 𝓊𝓈𝒾𝓃𝒼 𝒫𝓎𝓉𝒽𝓄𝓃 𝒸𝓄𝒹𝒺, 𝒤 𝒶𝓂 𝓅𝓇𝒺𝓅𝒶𝓇𝒾𝓃𝒼 𝒶 𝒨𝒮𝒢 for 4 times repetition
# Message 5 sent: 𝐁𝐲 𝐮𝐬𝐢𝐧𝐠 𝐏𝐲𝐭𝐡𝐨𝐧 𝐜𝐨𝐝𝐞, 𝐈 𝐚𝐦 𝐩𝐫𝐞𝐩𝐚𝐫𝐢𝐧𝐠 𝐚 𝐌𝐒𝐆 for 5 times repetition

# %%
import pywhatkit as kit
import time
import random

# Replace with recipient's WhatsApp number (include country code)
phone_number = "+91 9491201336"

# Number of times to send the message
count = 5  

# Custom function to convert text into script font
def to_script_font(text):
    script_upper = "𝒜𝐵𝒞𝒟𝐸𝐹𝒢𝐻𝐼𝒥𝒦𝐿𝑀𝒩𝒪𝒫𝒬𝑅𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵"
    script_lower = "𝒶𝒷𝒸𝒹𝑒𝒻𝑔𝒽𝒾𝒿𝓀𝓁𝓂𝓃𝑜𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏"
    normal_upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    normal_lower = "abcdefghijklmnopqrstuvwxyz"
    
    # Create translation tables
    trans_table = str.maketrans(normal_upper + normal_lower, script_upper + script_lower)
    
    return text.translate(trans_table)

for i in range(1, count + 1):
    # Convert the message to script font
    styled_message = to_script_font("By using Python code, I am preparing a MSG")

    # Create the final message with repetition count
    message = f"{styled_message} for {i} {'time' if i == 1 else 'times'} repetition"

    # Send the WhatsApp message instantly
    kit.sendwhatmsg_instantly(phone_number, message)
    
    print(f"Message {i} sent: {message}")  # Print message to verify
    
    time.sleep(5)  # Delay to prevent spam detection
# Out:
# Message 1 sent: 𝐵𝓎 𝓊𝓈𝒾𝓃𝑔 𝒫𝓎𝓉𝒽𝑜𝓃 𝒸𝑜𝒹𝑒, 𝐼 𝒶𝓂 𝓅𝓇𝑒𝓅𝒶𝓇𝒾𝓃𝑔 𝒶 𝑀𝒮𝒢 for 1 time repetition
# Message 2 sent: 𝐵𝓎 𝓊𝓈𝒾𝓃𝑔 𝒫𝓎𝓉𝒽𝑜𝓃 𝒸𝑜𝒹𝑒, 𝐼 𝒶𝓂 𝓅𝓇𝑒𝓅𝒶𝓇𝒾𝓃𝑔 𝒶 𝑀𝒮𝒢 for 2 times repetition
# Message 3 sent: 𝐵𝓎 𝓊𝓈𝒾𝓃𝑔 𝒫𝓎𝓉𝒽𝑜𝓃 𝒸𝑜𝒹𝑒, 𝐼 𝒶𝓂 𝓅𝓇𝑒𝓅𝒶𝓇𝒾𝓃𝑔 𝒶 𝑀𝒮𝒢 for 3 times repetition
# Message 4 sent: 𝐵𝓎 𝓊𝓈𝒾𝓃𝑔 𝒫𝓎𝓉𝒽𝑜𝓃 𝒸𝑜𝒹𝑒, 𝐼 𝒶𝓂 𝓅𝓇𝑒𝓅𝒶𝓇𝒾𝓃𝑔 𝒶 𝑀𝒮𝒢 for 4 times repetition
# Message 5 sent: 𝐵𝓎 𝓊𝓈𝒾𝓃𝑔 𝒫𝓎𝓉𝒽𝑜𝓃 𝒸𝑜𝒹𝑒, 𝐼 𝒶𝓂 𝓅𝓇𝑒𝓅𝒶𝓇𝒾𝓃𝑔 𝒶 𝑀𝒮𝒢 for 5 times repetition

# %%
import pywhatkit as kit
import time
import random

# Replace with recipient's WhatsApp number (include country code)
phone_number = "+919666781555"

# Number of times to send the message
count = 5  

# Fancy font mappings
font_styles = {
    "script": ("𝒜𝐵𝒞𝒟𝐸𝐹𝒢𝐻𝐼𝒥𝒦𝐿𝑀𝒩𝒪𝒫𝒬𝑅𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵", "𝒶𝒷𝒸𝒹𝑒𝒻𝒢𝒽𝒾𝒿𝓀𝓁𝓂𝓃𝑜𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏"),
    "bold": ("𝗔𝗕𝗖𝗗𝗘𝗙𝗚𝗛𝗜𝗝𝗞𝗟𝗠𝗡𝗢𝗣𝗤𝗥𝗦𝗧𝗨𝗩𝗪𝗫𝗬𝗭", "𝗮𝗯𝗰𝗱𝗲𝗳𝗴𝗵𝗶𝗷𝗸𝗹𝗺𝗻𝗼𝗽𝗾𝗿𝘀𝘵𝘶𝘷𝘄𝘅𝘆𝘇"),
    "italic": ("𝘈𝘉𝘊𝘋𝘌𝘍𝘎𝘏𝘐𝘑𝘒𝘓𝘔𝘕𝘖𝘗𝘘𝘙𝘚𝘛𝘜𝘝𝘞𝘟𝘠𝘡", "𝘢𝘣𝘤𝘥𝘦𝘧𝘨𝘩𝘪𝘫𝘬𝘭𝘮𝘯𝘰𝘱𝘲𝘳𝘴𝘵𝘶𝘷𝘸𝘹𝘺𝘻"),
    "gothic": ("𝕬𝕭𝕮𝕯𝕰𝕱𝕲𝕳𝕴𝕵𝕶𝕷𝕸𝕹𝕺𝕻𝕼𝕽𝕾𝕿𝖀𝖁𝖂𝖃𝖄𝖅", "𝖆𝖇𝖈𝖉𝖊𝖋𝖌𝖍𝖎𝖏𝖐𝖑𝖒𝖓𝖔𝖕𝖖𝖗𝖘𝖙𝖚𝖛𝖜𝖝𝖞𝖟")
}

# Function to convert text into a fancy font
def convert_to_fancy(text, style):
    upper, lower = font_styles[style]
    normal_upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    normal_lower = "abcdefghijklmnopqrstuvwxyz"
    
    trans_table = str.maketrans(normal_upper + normal_lower, upper + lower)
    return text.translate(trans_table)

time.sleep(5)  # Wait for WhatsApp Web to load properly

for i in range(1, count + 1):
    # Randomly select a font style
    random_style = random.choice(list(font_styles.keys()))

    # Convert the message into the selected font
    styled_message = convert_to_fancy("hi mama,sorry nnenu edipinchalli anikadu ganni sardhaki msg create cheysa with python emi anukoku once again sorry", random_style)

    # Create the final message with repetition count
    message = f"{styled_message} for {i} {'time' if i == 1 else 'times'} repetition"

    # Send the WhatsApp message
    kit.sendwhatmsg_instantly(phone_number, message)

    print(f"Message {i} sent in {random_style} font: {message}")  # Print message to verify

    time.sleep(5)  # Delay to prevent spam detection
# Out:
# Message 1 sent in gothic font: 𝖍𝖎 𝖒𝖆𝖒𝖆,𝖘𝖔𝖗𝖗𝖞 𝖓𝖓𝖊𝖓𝖚 𝖊𝖉𝖎𝖕𝖎𝖓𝖈𝖍𝖆𝖑𝖑𝖎 𝖆𝖓𝖎𝖐𝖆𝖉𝖚 𝖌𝖆𝖓𝖓𝖎 𝖘𝖆𝖗𝖉𝖍𝖆𝖐𝖎 𝖒𝖘𝖌 𝖈𝖗𝖊𝖆𝖙𝖊 𝖈𝖍𝖊𝖞𝖘𝖆 𝖜𝖎𝖙𝖍 𝖕𝖞𝖙𝖍𝖔𝖓 𝖊𝖒𝖎 𝖆𝖓𝖚𝖐𝖔𝖐𝖚 𝖔𝖓𝖈𝖊 𝖆𝖌𝖆𝖎𝖓 𝖘𝖔𝖗𝖗𝖞 for 1 time repetition
# Message 2 sent in script font: 𝒽𝒾 𝓂𝒶𝓂𝒶,𝓈𝑜𝓇𝓇𝓎 𝓃𝓃𝑒𝓃𝓊 𝑒𝒹𝒾𝓅𝒾𝓃𝒸𝒽𝒶𝓁𝓁𝒾 𝒶𝓃𝒾𝓀𝒶𝒹𝓊 𝒢𝒶𝓃𝓃𝒾 𝓈𝒶𝓇𝒹𝒽𝒶𝓀𝒾 𝓂𝓈𝒢 𝒸𝓇𝑒𝒶𝓉𝑒 𝒸𝒽𝑒𝓎𝓈𝒶 𝓌𝒾𝓉𝒽 𝓅𝓎𝓉𝒽𝑜𝓃 𝑒𝓂𝒾 𝒶𝓃𝓊𝓀𝑜𝓀𝓊 𝑜𝓃𝒸𝑒 𝒶𝒢𝒶𝒾𝓃 𝓈𝑜𝓇𝓇𝓎 for 2 times repetition
# Message 3 sent in italic font: 𝘩𝘪 𝘮𝘢𝘮𝘢,𝘴𝘰𝘳𝘳𝘺 𝘯𝘯𝘦𝘯𝘶 𝘦𝘥𝘪𝘱𝘪𝘯𝘤𝘩𝘢𝘭𝘭𝘪 𝘢𝘯𝘪𝘬𝘢𝘥𝘶 𝘨𝘢𝘯𝘯𝘪 𝘴𝘢𝘳𝘥𝘩𝘢𝘬𝘪 𝘮𝘴𝘨 𝘤𝘳𝘦𝘢𝘵𝘦 𝘤𝘩𝘦𝘺𝘴𝘢 𝘸𝘪𝘵𝘩 𝘱𝘺𝘵𝘩𝘰𝘯 𝘦𝘮𝘪 𝘢𝘯𝘶𝘬𝘰𝘬𝘶 𝘰𝘯𝘤𝘦 𝘢𝘨𝘢𝘪𝘯 𝘴𝘰𝘳𝘳𝘺 for 3 times repetition
# Message 4 sent in italic font: 𝘩𝘪 𝘮𝘢𝘮𝘢,𝘴𝘰𝘳𝘳𝘺 𝘯𝘯𝘦𝘯𝘶 𝘦𝘥𝘪𝘱𝘪𝘯𝘤𝘩𝘢𝘭𝘭𝘪 𝘢𝘯𝘪𝘬𝘢𝘥𝘶 𝘨𝘢𝘯𝘯𝘪 𝘴𝘢𝘳𝘥𝘩𝘢𝘬𝘪 𝘮𝘴𝘨 𝘤𝘳𝘦𝘢𝘵𝘦 𝘤𝘩𝘦𝘺𝘴𝘢 𝘸𝘪𝘵𝘩 𝘱𝘺𝘵𝘩𝘰𝘯 𝘦𝘮𝘪 𝘢𝘯𝘶𝘬𝘰𝘬𝘶 𝘰𝘯𝘤𝘦 𝘢𝘨𝘢𝘪𝘯 𝘴𝘰𝘳𝘳𝘺 for 4 times repetition
# Message 5 sent in bold font: 𝗵𝗶 𝗺𝗮𝗺𝗮,𝘀𝗼𝗿𝗿𝘆 𝗻𝗻𝗲𝗻𝘶 𝗲𝗱𝗶𝗽𝗶𝗻𝗰𝗵𝗮𝗹𝗹𝗶 𝗮𝗻𝗶𝗸𝗮𝗱𝘶 𝗴𝗮𝗻𝗻𝗶 𝘀𝗮𝗿𝗱𝗵𝗮𝗸𝗶 𝗺𝘀𝗴 𝗰𝗿𝗲𝗮𝘵𝗲 𝗰𝗵𝗲𝘆𝘀𝗮 𝘄𝗶𝘵𝗵 𝗽𝘆𝘵𝗵𝗼𝗻 𝗲𝗺𝗶 𝗮𝗻𝘶𝗸𝗼𝗸𝘶 𝗼𝗻𝗰𝗲 𝗮𝗴𝗮𝗶𝗻 𝘀𝗼𝗿𝗿𝘆 for 5 times repetition

# %%
import pywhatkit as kit
import time
import random

# Replace with recipient's WhatsApp number (include country code)
phone_number = "+918121240752"  # Change to actual number

# 10 Romantic Love Proposals
love_proposals = [
    "Rowdy, you are the reason my heart beats! 💖",
    "Rowdy, every love story is beautiful, but ours is my favorite! 😍",
    "Rowdy, you are my sunshine on a cloudy day! ☀️",
    "Rowdy, I can't imagine my life without you! ❤️",
    "Rowdy, you are the missing piece of my heart! 💞",
    "Rowdy, I promise to love you forever and always! 💓",
    "Rowdy, will you be mine for eternity? 💗",
    "Rowdy, my love for you grows stronger every day! 💕",
    "Rowdy, you are the most beautiful part of my life! 💖",
    "Rowdy, my heart belongs to you and only you! 😘❤️"
]

# Light & Thin Unicode Fonts
light_fonts = [
    "𝒜𝒷𝒸𝒹𝑒𝒻𝑔𝒽𝒾𝒿𝓀𝓁𝓂𝓃𝑜𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏",  # Soft Script
    "𝓐𝓫𝓬𝓭𝓮𝓯𝓰𝓱𝓲𝓳𝓴𝓵𝓶𝓷𝓸𝓹𝓺𝓻𝓼𝓽𝓾𝓿𝔀𝔁𝔂𝔃",  # Romantic Thin
    "𝒜𝐵𝒞𝒟𝐸𝐹𝒢𝐻𝐼𝒥𝒦𝐿𝑀𝒩𝒪𝒫𝒬𝑅𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵𝒶𝒷𝒸𝒹𝑒𝒻𝑔𝒽𝒾𝒿𝓀𝓁𝓂𝓃𝑜𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏",  # Fancy Light
]

# Function to apply a light font
def apply_light_font(text, font_style):
    normal_upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    normal_lower = "abcdefghijklmnopqrstuvwxyz"
    light_upper = font_style[:26]  # Uppercase letters
    light_lower = font_style[26:]  # Lowercase letters
    trans_table = str.maketrans(normal_upper + normal_lower, light_upper + light_lower)
    return text.translate(trans_table)

time.sleep(5)  # Wait for WhatsApp Web to load

for i, proposal in enumerate(love_proposals, 1):
    # Pick a light font
    selected_font = light_fonts[i % len(light_fonts)]
    
    # Apply the selected light font
    styled_message = apply_light_font(proposal, selected_font)

    # Send the WhatsApp message
    kit.sendwhatmsg_instantly(phone_number, styled_message)

    print(f"Message {i} sent in Light Font: {styled_message}")  # Print to verify

    time.sleep(5)  # Delay to prevent spam detection
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 45
#      42 selected_font = light_fonts[i % len(light_fonts)]
#      44 # Apply the selected light font
# ---> 45 styled_message = apply_light_font(proposal, selected_font)
#      47 # Send the WhatsApp message
#      48 kit.sendwhatmsg_instantly(phone_number, styled_message)
#
# Cell In[23], line 35, in apply_light_font(text, font_style)
#      33 light_upper = font_style[:26]  # Uppercase letters
#      34 light_lower = font_style[26:]  # Lowercase letters
# ---> 35 trans_table = str.maketrans(normal_upper + normal_lower, light_upper + light_lower)
#      36 return text.translate(trans_table)
#
# ValueError: the first two maketrans arguments must have equal length

# %%
import pywhatkit as kit
import time
import random

# ✅ Corrected Phone Number Format
phone_number = "+918121240752"  # No spaces, include country code

# 💕 10 Love Proposals for "Rowdy"
love_proposals = [
    "Rowdy, you are the reason my heart beats! 💖",
    "Rowdy, every love story is beautiful, but ours is my favorite! 😍",
    "Rowdy, you are my sunshine on a cloudy day! ☀️",
    "Rowdy, I can't imagine my life without you! ❤️",
    "Rowdy, you are the missing piece of my heart! 💞",
    "Rowdy, I promise to love you forever and always! 💓",
    "Rowdy, will you be mine for eternity? 💗",
    "Rowdy, my love for you grows stronger every day! 💕",
    "Rowdy, you are the most beautiful part of my life! 💖",
    "Rowdy, my heart belongs to you and only you! 😘❤️"
]

# 🎨 Use a Thin Unicode Font
def apply_light_font(text):
    thin_upper = "𝒜𝐵𝒞𝒟𝐸𝐹𝒢𝐻𝐼𝒥𝒦𝐿𝑀𝒩𝒪𝒫𝒬𝑅𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵"
    thin_lower = "𝒶𝒷𝒸𝒹𝑒𝒻𝑔𝒽𝒾𝒿𝓀𝓁𝓂𝓃𝑜𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏"
    normal_upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    normal_lower = "abcdefghijklmnopqrstuvwxyz"
    
    # Convert text into thin Unicode font
    trans_table = str.maketrans(normal_upper + normal_lower, thin_upper + thin_lower)
    return text.translate(trans_table)

# ✅ WhatsApp Web Delay
time.sleep(10)

# 🚀 Sending Messages in a Loop
for i, proposal in enumerate(love_proposals, 1):
    styled_message = apply_light_font(proposal)

    try:
        # ✅ Send Message Instantly
        kit.sendwhatmsg_instantly(phone_number, styled_message)

        print(f"✅ Message {i} sent: {styled_message}")  # Log the sent message

        time.sleep(5)  # 🛑 Avoid WhatsApp spam detection

    except Exception as e:
        print(f"❌ Error sending message {i}: {e}")
# Out:
# ✅ Message 1 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓎𝑜𝓊 𝒶𝓇𝑒 𝓉𝒽𝑒 𝓇𝑒𝒶𝓈𝑜𝓃 𝓂𝓎 𝒽𝑒𝒶𝓇𝓉 𝒷𝑒𝒶𝓉𝓈! 💖
# ✅ Message 2 sent: 𝑅𝑜𝓌𝒹𝓎, 𝑒𝓋𝑒𝓇𝓎 𝓁𝑜𝓋𝑒 𝓈𝓉𝑜𝓇𝓎 𝒾𝓈 𝒷𝑒𝒶𝓊𝓉𝒾𝒻𝓊𝓁, 𝒷𝓊𝓉 𝑜𝓊𝓇𝓈 𝒾𝓈 𝓂𝓎 𝒻𝒶𝓋𝑜𝓇𝒾𝓉𝑒! 😍
# ✅ Message 3 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓎𝑜𝓊 𝒶𝓇𝑒 𝓂𝓎 𝓈𝓊𝓃𝓈𝒽𝒾𝓃𝑒 𝑜𝓃 𝒶 𝒸𝓁𝑜𝓊𝒹𝓎 𝒹𝒶𝓎! ☀️
# ✅ Message 4 sent: 𝑅𝑜𝓌𝒹𝓎, 𝐼 𝒸𝒶𝓃'𝓉 𝒾𝓂𝒶𝑔𝒾𝓃𝑒 𝓂𝓎 𝓁𝒾𝒻𝑒 𝓌𝒾𝓉𝒽𝑜𝓊𝓉 𝓎𝑜𝓊! ❤️
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 42
#      38 styled_message = apply_light_font(proposal)
#      40 try:
#      41     # ✅ Send Message Instantly
# ---> 42     kit.sendwhatmsg_instantly(phone_number, styled_message)
#      44     print(f"✅ Message {i} sent: {styled_message}")  # Log the sent message
#      46     time.sleep(5)  # 🛑 Avoid WhatsApp spam detection
#
# File ~\anaconda3\Lib\site-packages\pywhatkit\whats.py:31, in sendwhatmsg_instantly(phone_no, message, wait_time, tab_close, close_time)
#      29 time.sleep(4)
# ...

# %%
import pywhatkit as kit
import time
import random

# ✅ Corrected Phone Number Format
phone_number = "+919666781555"  # No spaces, include country code

# 💕 10 Love Proposals for "Rowdy"
love_proposals = [
    "Rowdy, you are the reason my heart beats! 💖",
    "Rowdy, every love story is beautiful, but ours is my favorite! 😍",
    "Rowdy, you are my sunshine on a cloudy day! ☀️",
    "Rowdy, I can't imagine my life without you! ❤️",
    "Rowdy, you are the missing piece of my heart! 💞",
    "Rowdy, I promise to love you forever and always! 💓",
    "Rowdy, will you be mine for eternity? 💗",
    "Rowdy, my love for you grows stronger every day! 💕",
    "Rowdy, you are the most beautiful part of my life! 💖",
    "Rowdy, my heart belongs to you and only you! 😘❤️"
]

# 🎨 Use a Thin Unicode Font
def apply_light_font(text):
    thin_upper = "𝒜𝐵𝒞𝒟𝐸𝐹𝒢𝐻𝐼𝒥𝒦𝐿𝑀𝒩𝒪𝒫𝒬𝑅𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵"
    thin_lower = "𝒶𝒷𝒸𝒹𝑒𝒻𝑔𝒽𝒾𝒿𝓀𝓁𝓂𝓃𝑜𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏"
    normal_upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    normal_lower = "abcdefghijklmnopqrstuvwxyz"
    
    # Convert text into thin Unicode font
    trans_table = str.maketrans(normal_upper + normal_lower, thin_upper + thin_lower)
    return text.translate(trans_table)

# ✅ WhatsApp Web Delay
time.sleep(10)

# 🚀 Sending Messages in a Loop
for i, proposal in enumerate(love_proposals, 1):
    styled_message = apply_light_font(proposal)

    try:
        # ✅ Send Message Instantly
        kit.sendwhatmsg_instantly(phone_number, styled_message)

        print(f"✅ Message {i} sent: {styled_message}")  # Log the sent message

        time.sleep(5)  # 🛑 Avoid WhatsApp spam detection

    except Exception as e:
        print(f"❌ Error sending message {i}: {e}")
# Out:
# ✅ Message 1 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓎𝑜𝓊 𝒶𝓇𝑒 𝓉𝒽𝑒 𝓇𝑒𝒶𝓈𝑜𝓃 𝓂𝓎 𝒽𝑒𝒶𝓇𝓉 𝒷𝑒𝒶𝓉𝓈! 💖
# ✅ Message 2 sent: 𝑅𝑜𝓌𝒹𝓎, 𝑒𝓋𝑒𝓇𝓎 𝓁𝑜𝓋𝑒 𝓈𝓉𝑜𝓇𝓎 𝒾𝓈 𝒷𝑒𝒶𝓊𝓉𝒾𝒻𝓊𝓁, 𝒷𝓊𝓉 𝑜𝓊𝓇𝓈 𝒾𝓈 𝓂𝓎 𝒻𝒶𝓋𝑜𝓇𝒾𝓉𝑒! 😍
# ✅ Message 3 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓎𝑜𝓊 𝒶𝓇𝑒 𝓂𝓎 𝓈𝓊𝓃𝓈𝒽𝒾𝓃𝑒 𝑜𝓃 𝒶 𝒸𝓁𝑜𝓊𝒹𝓎 𝒹𝒶𝓎! ☀️
# ✅ Message 4 sent: 𝑅𝑜𝓌𝒹𝓎, 𝐼 𝒸𝒶𝓃'𝓉 𝒾𝓂𝒶𝑔𝒾𝓃𝑒 𝓂𝓎 𝓁𝒾𝒻𝑒 𝓌𝒾𝓉𝒽𝑜𝓊𝓉 𝓎𝑜𝓊! ❤️
# ✅ Message 5 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓎𝑜𝓊 𝒶𝓇𝑒 𝓉𝒽𝑒 𝓂𝒾𝓈𝓈𝒾𝓃𝑔 𝓅𝒾𝑒𝒸𝑒 𝑜𝒻 𝓂𝓎 𝒽𝑒𝒶𝓇𝓉! 💞
# ✅ Message 6 sent: 𝑅𝑜𝓌𝒹𝓎, 𝐼 𝓅𝓇𝑜𝓂𝒾𝓈𝑒 𝓉𝑜 𝓁𝑜𝓋𝑒 𝓎𝑜𝓊 𝒻𝑜𝓇𝑒𝓋𝑒𝓇 𝒶𝓃𝒹 𝒶𝓁𝓌𝒶𝓎𝓈! 💓
# ✅ Message 7 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓌𝒾𝓁𝓁 𝓎𝑜𝓊 𝒷𝑒 𝓂𝒾𝓃𝑒 𝒻𝑜𝓇 𝑒𝓉𝑒𝓇𝓃𝒾𝓉𝓎? 💗
# ✅ Message 8 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓂𝓎 𝓁𝑜𝓋𝑒 𝒻𝑜𝓇 𝓎𝑜𝓊 𝑔𝓇𝑜𝓌𝓈 𝓈𝓉𝓇𝑜𝓃𝑔𝑒𝓇 𝑒𝓋𝑒𝓇𝓎 𝒹𝒶𝓎! 💕
# ✅ Message 9 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓎𝑜𝓊 𝒶𝓇𝑒 𝓉𝒽𝑒 𝓂𝑜𝓈𝓉 𝒷𝑒𝒶𝓊𝓉𝒾𝒻𝓊𝓁 𝓅𝒶𝓇𝓉 𝑜𝒻 𝓂𝓎 𝓁𝒾𝒻𝑒! 💖
# ✅ Message 10 sent: 𝑅𝑜𝓌𝒹𝓎, 𝓂𝓎 𝒽𝑒𝒶𝓇𝓉 𝒷𝑒𝓁𝑜𝓃𝑔𝓈 𝓉𝑜 𝓎𝑜𝓊 𝒶𝓃𝒹 𝑜𝓃𝓁𝓎 𝓎𝑜𝓊! 😘❤️

# %%
import pywhatkit as kit
import time

# ✅ Replace with the recipient's WhatsApp number (include country code)
phone_number = "+919491201336"  # Example format: "+91XXXXXXXXXX"

# 💖 10 Love Proposals for "Rowdy" (Clear & Readable with Emoji at the End)
love_proposals = [
    "*Rowdy, my love for you is infinite!* 💖",
    "*Rowdy, you make my life beautiful!* 😍",
    "*Rowdy, I can't imagine my life without you!* 💕",
    "*Rowdy, you are the reason for my happiness!* 💞",
    "*Rowdy, I want to grow old with you!* 💓",
    "*Rowdy, my heart beats only for you!* 💗",
    "*Rowdy, will you be mine forever?* ❤️",
    "*Rowdy, you are my world and my everything!* 😘",
    "*Rowdy, I love you more than words can express!* 💖",
    "*Rowdy, my heart belongs to you forever!* 💑"
]

# ✅ Ensure WhatsApp Web is Open
time.sleep(10)

# 🚀 Sending Messages in a Loop
for i, proposal in enumerate(love_proposals, 1):
    try:
        # ✅ Send Message Instantly
        kit.sendwhatmsg_instantly(phone_number, proposal)

        print(f"✅ Message {i} sent: {proposal}")  # Log the sent message

        time.sleep(5)  # 🛑 Prevent WhatsApp spam detection

    except Exception as e:
        print(f"❌ Error sending message {i}: {e}")
# Out:
# ✅ Message 1 sent: *Rowdy, my love for you is infinite!* 💖
# ✅ Message 2 sent: *Rowdy, you make my life beautiful!* 😍
# ✅ Message 3 sent: *Rowdy, I can't imagine my life without you!* 💕
# ✅ Message 4 sent: *Rowdy, you are the reason for my happiness!* 💞
# ✅ Message 5 sent: *Rowdy, I want to grow old with you!* 💓
# ✅ Message 6 sent: *Rowdy, my heart beats only for you!* 💗
# ✅ Message 7 sent: *Rowdy, will you be mine forever?* ❤️
# ✅ Message 8 sent: *Rowdy, you are my world and my everything!* 😘
# ✅ Message 9 sent: *Rowdy, I love you more than words can express!* 💖
# ✅ Message 10 sent: *Rowdy, my heart belongs to you forever!* 💑
