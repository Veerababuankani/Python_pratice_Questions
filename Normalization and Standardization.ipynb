# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [raw]
# in every data set we have differnt columns has different units
# in evrey dataset we have differnt colunms has values varies from -int to int
# it is very important standardize the data ,make sure all the column values under same range
# to achive this we have two methods
# *normalization
# *standardization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
#####################################
Min=adult_df['education-num'].min()
Max=adult_df['education-num'].max()
Dr=Max-Min
Nr=adult_df['education-num']-Min
adult_df['education-num_nor']=Nr/Dr

# %%
adult_df[['education-num','education-num_nor']]
# Out:
#        education-num  education-num_nor
# 0                 13           0.800000
# 1                 13           0.800000
# 2                  9           0.533333
# 3                  7           0.400000
# 4                 13           0.800000
# ...              ...                ...
# 32556             12           0.733333
# 32557              9           0.533333
# 32558              9           0.533333
# 32559              9           0.533333
# 32560              9           0.533333
#
# [32561 rows x 2 columns]

# %%
adult_df['education-num_nor'].max(),adult_df['education-num_nor'].min()
# Out:
# (1.0, 0.0)

# %%
adult_df['education-num'].max(),adult_df['education-num'].min()
# Out:
# (16, 1)

# %%
max_id,min_id=adult_df['education-num_nor'].idxmax(),adult_df['education-num_nor'].idxmin()
max_id,min_id
# Out:
# (20, 224)

# %%
adult_df[['education-num','education-num_nor']].iloc[[max_id,min_id]]
# Out:
#      education-num  education-num_nor
# 20              16                1.0
# 224              1                0.0

# %% [raw]
# minmaxscaler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
######################################################################################
from sklearn.preprocessing import MinMaxScaler
###############################################################
mns=MinMaxScaler()
################################################################
adult_df['education-num-nor']=mns.fit_transform(adult_df[['education-num']])

# %%
v1=np.array([[[1,2,3,4]]])

# %%
v1.ndim
# Out:
# 3

# %%
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
adult_df[['education-num-nor','education-num']]
# Out:
#        education-num-nor  education-num
# 0               0.800000             13
# 1               0.800000             13
# 2               0.533333              9
# 3               0.400000              7
# 4               0.800000             13
# ...                  ...            ...
# 32556           0.733333             12
# 32557           0.533333              9
# 32558           0.533333              9
# 32559           0.533333              9
# 32560           0.533333              9
#
# [32561 rows x 2 columns]

# %%
Mean=adult_df['education-num'].mean()
std=adult_df['education-num'].std()
nr=adult_df['education-num']-Mean
adult_df["education-num-zcore"]=nr/std

# %%
adult_df[['education-num','education-num-zcore']]
# Out:
#        education-num  education-num-zcore
# 0                 13             1.134721
# 1                 13             1.134721
# 2                  9            -0.420053
# 3                  7            -1.197440
# 4                 13             1.134721
# ...              ...                  ...
# 32556             12             0.746028
# 32557              9            -0.420053
# 32558              9            -0.420053
# 32559              9            -0.420053
# 32560              9            -0.420053
#
# [32561 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.boxplot(adult_df['education-num'])
plt.subplot(1,2,2)
plt.boxplot(adult_df['education-num-zcore'])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
######################################################################################
from sklearn.preprocessing import StandardScaler
###############################################################
ss=StandardScaler()
############################################################
ss.fit_transform(adult_df[['education-num']])
# Out:
# array([[ 1.13473876],
#        [ 1.13473876],
#        [-0.42005962],
#        ...,
#        [-0.42005962],
#        [-0.42005962],
#        [-0.42005962]])
