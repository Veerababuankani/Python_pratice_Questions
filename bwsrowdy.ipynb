# %%
#qr code for vedio
import qrcode

# URL of the video
video_url = "https://www.youtube.com/watch?v=dQw4w9WgXcQ"

# Create QR code instance
qr = qrcode.QRCode(
    version=1,  # Controls the size of the QR Code (1 is the smallest)
    error_correction=qrcode.constants.ERROR_CORRECT_L,  # Error correction level
    box_size=10,  # Size of each box in pixels
    border=4,  # Border thickness (minimum is 4)
)

# Add the video URL to the QR code
qr.add_data(video_url)
qr.make(fit=True)

# Generate the QR code image
qr_image = qr.make_image(fill_color="black", back_color="white")

# Save the QR code to a file
qr_image.save("video_qrcode.png")

print("QR code generated and saved as 'video_qrcode.png'.")
# Out:
# QR code generated and saved as 'video_qrcode.png'.

# %%
pip install qrcode
pip show qrcode
# Out:
#   Cell In[3], line 1
#     pip install qrcode
#         ^
# SyntaxError: invalid syntax

# %%
pip install qrcode[pil]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode

# Video URL
video_url = "https://drive.google.com/file/d/1nhOYlzRIh8QprrMjGbtwq2AXLeP6DApo/view?usp=drive_link"

# Generate QR code
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)
qr.add_data(video_url)
qr.make(fit=True)

# Create an image from the QR Code instance
img = qr.make_image(fill='black', back_color='white')

# Save the image
img.save("video_qr_code.png")

# %%
from PIL import Image

# Open the generated QR code image
img = Image.open("video_qr_code.png")
img.show()

# %%
pip install qrcode[pil]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import qrcode

# Video URL
video_url = "https://drive.google.com/file/d/1BpX3sLUI3pKEoKn1DhihT6vcBOQi9tyz/view?usp=drive_link"

# Generate QR code
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)
qr.add_data(video_url)
qr.make(fit=True)

# Create an image from the QR Code instance
img = qr.make_image(fill='black', back_color='white')

# Save the image
img.save("video_qr_code.png")

# %%
from PIL import Image

# Open the generated QR code image
img = Image.open("video_qr_code.png")
img.show()
