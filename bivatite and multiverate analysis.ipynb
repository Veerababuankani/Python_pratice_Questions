# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")

# %%
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
adult_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
adult_df['education'].value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
adult_df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
adult_df['race'].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
con1=adult_df['workclass']=='Private'
con2=adult_df['race']=='White'
con=con1&con2
len(adult_df[con])
# Out:
# 19404

# %%
adult_df['workclass'].unique()
adult_df['workclass'].value_counts().keys()
# Out:
# Index(['Private', 'Self-emp-not-inc', 'Local-gov', '?', 'State-gov',
#        'Self-emp-inc', 'Federal-gov', 'Without-pay', 'Never-worked'],
#       dtype='object', name='workclass')

# %%
labels=adult_df['workclass'].unique()
for i in labels:
    con1=adult_df['workclass']=='i'
    con2=adult_df['race']=='White'
    con=con1&con2
    print(len(adult_df[con]))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
labels=adult_df['workclass'].unique()
certified_count=[]
for i in labels:
    con1=adult_df['workclass']=='i'
    con2=adult_df['race']=='White'
    con=con1&con2
    certified_count.append(len((adult_df[con])))
labels,certified_count
pd.DataFrame(zip(labels,certified_count),
            columns=['workclass','sex'])
# Out:
#           workclass  sex
# 0         State-gov    0
# 1  Self-emp-not-inc    0
# 2           Private    0
# 3       Federal-gov    0
# 4         Local-gov    0
# 5                 ?    0
# 6      Self-emp-inc    0
# 7       Without-pay    0
# 8      Never-worked    0

# %%
labels=adult_df['workclass'].unique()
certified_count=[]
for i in labels:
    con1=adult_df['workclass']=='i'
    con2=adult_df['race']=='White'
    con=con1&con2
    certified_count.append(len((adult_df[con])))
labels,certified_count
pd.DataFrame(zip(labels,certified_count),
            columns=['workclass','sex']).set_index('workclass')
# Out:
#                   sex
# workclass
# State-gov           0
# Self-emp-not-inc    0
# Private             0
# Federal-gov         0
# Local-gov           0
# ?                   0
# Self-emp-inc        0
# Without-pay         0
# Never-worked        0

# %%
col1=adult_df['workclass']
col2=adult_df['sex']
result1=pd.crosstab(col1,col2)
result1
# Out:
# sex               Female   Male
# workclass
# ?                    839    997
# Federal-gov          315    645
# Local-gov            835   1258
# Never-worked           2      5
# Private             7752  14944
# Self-emp-inc         135    981
# Self-emp-not-inc     399   2142
# State-gov            489    809
# Without-pay            5      9

# %%
result1.plot(kind='bar')
plt.show()

# %%
col1=adult_df['workclass']
col2=adult_df['education']
col3=adult_df['sex']
col=[col2,col3]
col=[col2,col3]
result2=pd.crosstab(col1,col)
result2
# Out:
# education          10th        11th        12th      1st-4th      5th-6th  \
# sex              Female Male Female Male Female Male  Female Male  Female
# workclass
# ?                    42   58     59   59     18   22       3    9      10
# Federal-gov           2    4      6    3      2    3       0    0       0
# Local-gov             7   24     10   26      5   14       1    3       3
# Never-worked          0    2      1    0      0    0       0    0       0
# Private             226  469    337  586    108  225      37   99      67
# Self-emp-inc          4   15      1   13      1    6       0    2       0
# Self-emp-not-inc     11   56     13   47      5   14       4    9       3
# State-gov             3   10      5    9      5    5       1    0       1
# Without-pay           0    0      0    0      0    0       0    0       0
#
# education              ... HS-grad       Masters      Preschool       \
# sex              Male  ...  Female  Male  Female Male    Female Male
# ...

# %%
result2.plot(kind='bar')
plt.show()

# %%
#numerical vs numerical
#scatter

# %%
x=[1,2,3,4,5]
y=[11,12,13,14,15]
plt.scatter(x,y)
plt.show()

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)

# %%
dtypes=dict(adult_df.dtypes)
num=[i for i in dtypes if dtypes[i]=='int64' or dtypes[i]=='float64']
num
# Out:
# ['age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
col1=adult_df['workclass']
col2=adult_df['hours-per-week']
plt.scatter(col1,col2)

# %%
adult_df.corr(numeric_only=True)
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
plt.scatter(adult_df['hours-per-week'],adult_df['fnlwgt'])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
adult_df=pd.read_csv("D:\\ADITI DIGITAL SOLUTIONS-DS\\ds notes\\adult.csv")
adult_df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
#corr function
adult_df.corr(numeric_only=True)
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
#matrix
#showing values in matrix
#showing values a picture: heatmap

# %%
corr_data=adult_df.corr(numeric_only=True)
sns.heatmap(corr_data)
# Out:
# <Axes: >

# %%
corr_data=adult_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(adult_df['age'],adult_df['education-num'])
